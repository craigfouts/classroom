# %%
println("Hello, World!")
# Out:
# Hello, World!

# %%
my_answer = 42
typeof(my_answer)
# Out:
# Int64

# %%
my_pi = 3.14159
typeof(my_pi)
# Out:
# Float64

# %%
🙂 = "Smiley Face"
typeof(🙂)
# Out:
# String
